# %%
import gym 
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
environment_name = "CartPole-v0"
env = gym.make(environment_name)

# %%
episodes = 5
for episode in range(1,episodes+1):
    state=env.reset()
    done=False
    score = 0
    
    while not done:
        env.render()
        action=env.action_space.sample()
        n_state,reward,done,info = env.step(action)
        score+=reward
    print('Episode:{} Score;{}'.format(episode,score))
env.close()
# Out:
# Episode:1 Score;29.0
# Episode:2 Score;21.0
# Episode:3 Score;26.0
# Episode:4 Score;30.0
# Episode:5 Score;35.0

# %%
env.close()

# %%
import os
log_path = os.path.join('Training', 'logs')

# %%
log_path
# Out:
# 'Training/logs'

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose = 1, tensorboard_log = log_path)
# Out:
# Using cuda device

# %%
PPO??

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training/logs/PPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 756  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 741         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012010581 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.00245     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.73        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0177     |
# |    value_loss           | 49.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 735         |
# |    iterations           | 3           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.019173384 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.66       |
# |    explained_variance   | 0.0945      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.33        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0222     |
# |    value_loss           | 26.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 731          |
# |    iterations           | 4            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0030447207 |
# |    clip_fraction        | 0.0655       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.634       |
# |    explained_variance   | 0.212        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.4         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0159      |
# |    value_loss           | 50.6         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 729        |
# |    iterations           | 5          |
# |    time_elapsed         | 14         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.00749315 |
# |    clip_fraction        | 0.0718     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.608     |
# |    explained_variance   | 0.373      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 17.6       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0172    |
# |    value_loss           | 53.8       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 725         |
# |    iterations           | 6           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012395019 |
# |    clip_fraction        | 0.0813      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.581      |
# |    explained_variance   | 0.564       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.8        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0182     |
# |    value_loss           | 54.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 722         |
# |    iterations           | 7           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.014488593 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.577      |
# |    explained_variance   | 0.751       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.3        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0141     |
# |    value_loss           | 45.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 8           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.004370648 |
# |    clip_fraction        | 0.025       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.556      |
# |    explained_variance   | 0.0594      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.9        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00462    |
# |    value_loss           | 94.8        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 723          |
# |    iterations           | 9            |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0077283685 |
# |    clip_fraction        | 0.032        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.572       |
# |    explained_variance   | 0.375        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.69         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00203     |
# |    value_loss           | 82           |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 725         |
# |    iterations           | 10          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.003986869 |
# |    clip_fraction        | 0.0083      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.554      |
# |    explained_variance   | 0.356       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50.4        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00248    |
# |    value_loss           | 84.9        |
# -----------------------------------------

# %%
PPO_Path = os.path.join('Training','Saved Models','PPo_Model_cartpole')

# %%
model.save(PPO_Path)
# Out:
# /home/vedant/miniconda3/envs/tensorflow/lib/python3.7/site-packages/stable_baselines3/common/save_util.py:276: UserWarning: Path 'Training/Saved Models' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")

# %%
del model

# %%
model = PPO.load(PPO_Path,env=env)

# %%
model.learn(total_timesteps=1000)
# Out:
# Logging to Training/logs/PPO_2
# -----------------------------
# | time/              |      |
# |    fps             | 1099 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------

# %%
evaluate_policy(model,env,n_eval_episodes=10,render=True)
# Out:
# /home/vedant/miniconda3/envs/tensorflow/lib/python3.7/site-packages/stable_baselines3/common/evaluation.py:69: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   UserWarning,
# (200.0, 0.0)

# %%
env.close()

# %%
episodes = 5
for episode in range(1,episodes+1):
    obs=env.reset()
    done=False
    score = 0
    
    while not done:
        env.render()
        action,_=model.predict(obs)
        obs,reward,done,info = env.step(action)
        score+=reward
    print('Episode:{} Score;{}'.format(episode,score))
env.close()
# Out:
# Episode:1 Score;[200.]
# Episode:2 Score;[200.]
# Episode:3 Score;[200.]
# Episode:4 Score;[200.]
# Episode:5 Score;[200.]

# %%
training_log_path=os.path.join(log_path,'PPO_1')

# %%
training_log_path
# Out:
# 'Training/logs/PPO_1'

# %%
# !tensorboard --logdir={training_log_path}
# Out:
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.5.0 at http://localhost:6006/ (Press CTRL+C to quit)

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path=os.path.join('Training','Saved Models')

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=200, verbose=1)
eval_callback = EvalCallback(env, 
                             callback_on_new_best=stop_callback, 
                             eval_freq=10000, 
                             best_model_save_path=save_path, 
                             verbose=1)

# %%
model = PPO('MlpPolicy', env, verbose = 1, tensorboard_log = log_path)
# Out:
# Using cuda device

# %%
model.learn(total_timesteps=20000,callback=eval_callback)
# Out:
# Logging to Training/logs/PPO_3
# -----------------------------
# | time/              |      |
# |    fps             | 551  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 585          |
# |    iterations           | 2            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0036954272 |
# |    clip_fraction        | 0.0837       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.687       |
# |    explained_variance   | 0.00133      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.55         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0125      |
# |    value_loss           | 53.2         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 603         |
# |    iterations           | 3           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008206595 |
# |    clip_fraction        | 0.0541      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 0.066       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.8        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0159     |
# |    value_loss           | 40.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 613         |
# |    iterations           | 4           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.006028537 |
# |    clip_fraction        | 0.0828      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.639      |
# |    explained_variance   | 0.266       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.7        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0194     |
# |    value_loss           | 55.3        |
# -----------------------------------------
# /home/vedant/miniconda3/envs/tensorflow/lib/python3.7/site-packages/stable_baselines3/common/evaluation.py:69: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   UserWarning,
# Eval num_timesteps=10000, episode_reward=194.80 +/- 10.40
# Episode length: 194.80 +/- 10.40
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 195         |
# |    mean_reward          | 195         |
# | time/                   |             |
# |    fps                  | 598         |
# |    iterations           | 5           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011146549 |
# |    clip_fraction        | 0.0874      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.607      |
# |    explained_variance   | 0.284       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.6        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0189     |
# |    value_loss           | 65.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 600         |
# |    iterations           | 6           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011443874 |
# |    clip_fraction        | 0.0782      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.595      |
# |    explained_variance   | 0.49        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.2        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 60.7        |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 605           |
# |    iterations           | 7             |
# |    time_elapsed         | 23            |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 0.00036119425 |
# |    clip_fraction        | 0.0249        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.589        |
# |    explained_variance   | 0.414         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 31.6          |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.00574      |
# |    value_loss           | 61.8          |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 606         |
# |    iterations           | 8           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006829299 |
# |    clip_fraction        | 0.0345      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.577      |
# |    explained_variance   | 0.494       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.7        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0055     |
# |    value_loss           | 73.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 608         |
# |    iterations           | 9           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008536965 |
# |    clip_fraction        | 0.0559      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.566      |
# |    explained_variance   | 0.701       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.9        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00525    |
# |    value_loss           | 56.2        |
# -----------------------------------------
# Eval num_timesteps=20000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# New best mean reward!
# Stopping training because the mean reward 200.00  is above the threshold 200

# %%
net_arch=[dict(pi=[128, 128, 128, 128], vf=[128, 128, 128, 128])]

# %%
model = PPO('MlpPolicy', env, verbose = 1, policy_kwargs={'net_arch': net_arch})
# Out:
# Using cuda device

# %%
model.learn(total_timesteps=20000,callback=eval_callback)
# Out:
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 200        |
# |    mean_reward          | 200        |
# | time/                   |            |
# |    fps                  | 947        |
# |    iterations           | 1          |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 2048       |
# | train/                  |            |
# |    approx_kl            | 0.00551892 |
# |    clip_fraction        | 0.0202     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.544     |
# |    explained_variance   | 0.355      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 16.2       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.00217   |
# |    value_loss           | 94.5       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 669         |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011115029 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.682      |
# |    explained_variance   | 0.000316    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.14        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0214     |
# |    value_loss           | 18.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 611         |
# |    iterations           | 3           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.016667191 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.642      |
# |    explained_variance   | 0.467       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.83        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0321     |
# |    value_loss           | 23          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 581          |
# |    iterations           | 4            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0153675955 |
# |    clip_fraction        | 0.155        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.602       |
# |    explained_variance   | 0.469        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.9         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0281      |
# |    value_loss           | 39.3         |
# ------------------------------------------
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | 200          |
# | time/                   |              |
# |    fps                  | 543          |
# |    iterations           | 5            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0062980396 |
# |    clip_fraction        | 0.137        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.571       |
# |    explained_variance   | 0.503        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.5         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0163      |
# |    value_loss           | 37           |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 539         |
# |    iterations           | 6           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011384611 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.546      |
# |    explained_variance   | 0.783       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.49        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0124     |
# |    value_loss           | 27.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 538         |
# |    iterations           | 7           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.005616945 |
# |    clip_fraction        | 0.0617      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.537      |
# |    explained_variance   | 0.631       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.2        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00328    |
# |    value_loss           | 44.3        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 535          |
# |    iterations           | 8            |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0017911573 |
# |    clip_fraction        | 0.0316       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.534       |
# |    explained_variance   | 0.785        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.4         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0011      |
# |    value_loss           | 41.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 533          |
# |    iterations           | 9            |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0026452246 |
# |    clip_fraction        | 0.032        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.535       |
# |    explained_variance   | 0.648        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.6         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00193     |
# |    value_loss           | 72.6         |
# ------------------------------------------
# Eval num_timesteps=20000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | 200          |
# | time/                   |              |
# |    fps                  | 521          |
# |    iterations           | 10           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0042233625 |
# |    clip_fraction        | 0.0512       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.512       |
# |    explained_variance   | 0.546        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.2         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00304     |
# |    value_loss           | 84.4         |
# ------------------------------------------

# %%
from stable_baselines3 import DQN

# %%
model = DQN('MlpPolicy', env, verbose = 1, tensorboard_log = log_path)
# Out:
# Using cuda device

# %%
model.learn(total_timesteps=20000,callback=eval_callback)
# Out:
# Logging to Training/logs/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.955    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 3613     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 95       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.922    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 4599     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 165      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.876    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 5818     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 262      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.838    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 6315     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 342      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.779    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 7082     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 466      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.742    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 6954     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 544      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.709    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 7032     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 612      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.657    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 7235     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 722      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.596    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 7645     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 850      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.533    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 7972     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 983      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.498    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 8040     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1057     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.466    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 8058     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1125     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.388    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 8301     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1288     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.36     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 8352     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1347     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.316    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 8435     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1440     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.244    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 8651     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1591     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.203    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 8635     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1677     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.167    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 8687     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1753     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.138    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 8715     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1815     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.0628   |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 8836     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1973     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 8876     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2045     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 9061     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2181     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 9109     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2252     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 9150     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2350     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 9202     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2448     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 9267     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2545     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 9317     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2663     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 9367     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2739     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 9378     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2823     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 9414     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2899     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 9389     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2972     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 9427     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3054     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 9265     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3233     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 9162     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3298     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 9104     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3383     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 9100     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3435     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 9137     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3533     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 9138     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3612     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 9184     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3703     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 9200     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3791     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 9184     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3833     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 9217     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3899     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 9256     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4012     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 9295     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4111     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 9331     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4196     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 9302     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4257     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 9329     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4358     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 9345     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4454     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 9368     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4548     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 9404     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4625     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 9436     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4753     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 9379     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4823     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 9345     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4884     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 9335     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4980     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 9318     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5045     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 9324     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5151     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 9333     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5209     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 9327     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5282     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 9344     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5360     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 9358     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5443     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 9373     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5526     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 9391     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5629     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 9406     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5683     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 9404     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5760     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 9444     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5875     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 9457     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5954     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 9466     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6033     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 9508     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6150     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 9539     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6294     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 9544     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6362     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 9560     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6467     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 9553     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6537     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 9570     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6605     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 9531     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6771     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 9485     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6866     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 9479     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6927     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 9482     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6992     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 9499     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7087     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 9517     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7156     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 9541     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7246     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 9533     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7315     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 9558     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7417     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 9572     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7539     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 9580     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7614     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 9592     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7695     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 9598     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7783     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 9605     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7853     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 9628     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7936     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 9591     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7989     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 9574     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8118     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 9562     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8203     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 9550     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8295     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 9542     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8382     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 9585     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8529     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 9552     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8626     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 9522     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8692     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 9516     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8761     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 9533     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8865     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 9560     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8972     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 9556     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9039     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 9574     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9122     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 9576     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9175     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 9581     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9278     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 9602     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9384     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 9603     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9458     |
# ----------------------------------
# Eval num_timesteps=9520, episode_reward=9.00 +/- 0.89
# Episode length: 9.00 +/- 0.89
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 9        |
# |    mean_reward      | 9        |
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 9404     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9569     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 9400     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9654     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 9396     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9777     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 9388     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9878     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 9399     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10046    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 9396     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10145    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 9401     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10217    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 9427     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10382    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 9441     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10467    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 9430     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10524    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 9440     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10617    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 9423     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10730    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 9393     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10777    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 9395     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10842    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 9395     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10959    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 9392     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11046    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 9358     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11126    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 9341     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11229    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 9327     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11297    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 9335     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11419    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 9328     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11486    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 9337     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11564    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 9318     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11630    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 9311     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11705    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 9327     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11841    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 9328     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11911    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 9320     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11960    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 9328     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12029    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 9334     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12115    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 9328     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12173    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 9331     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12233    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 9359     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12362    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 9358     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12458    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 9369     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12540    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 9324     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12648    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 9328     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12732    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 9321     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12832    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 9329     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12949    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 9318     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13031    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 9313     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13158    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 9339     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13291    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 9350     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13384    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 9362     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13463    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 9364     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13529    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 9361     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13601    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 9359     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13648    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 9350     |
# ...
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 9437     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15551    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 704      |
# |    fps              | 9445     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15650    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 708      |
# |    fps              | 9447     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15718    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 712      |
# |    fps              | 9449     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15788    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 716      |
# |    fps              | 9457     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15918    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 9467     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15993    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 724      |
# |    fps              | 9459     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16054    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 728      |
# |    fps              | 9450     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16166    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 732      |
# |    fps              | 9440     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16233    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 736      |
# |    fps              | 9432     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16311    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 9423     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16372    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 744      |
# |    fps              | 9397     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16455    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 748      |
# |    fps              | 9389     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16585    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 752      |
# |    fps              | 9382     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16671    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 756      |
# |    fps              | 9388     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16779    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 760      |
# |    fps              | 9395     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16867    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 764      |
# |    fps              | 9406     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16962    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 768      |
# |    fps              | 9404     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17056    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 772      |
# |    fps              | 9420     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17182    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 776      |
# |    fps              | 9388     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17269    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 780      |
# |    fps              | 9353     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17362    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 784      |
# |    fps              | 9337     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17444    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 788      |
# |    fps              | 9341     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17543    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 792      |
# |    fps              | 9351     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17628    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 796      |
# |    fps              | 9368     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17734    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 9375     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17835    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 804      |
# |    fps              | 9381     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17926    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 808      |
# |    fps              | 9381     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18002    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 812      |
# |    fps              | 9390     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18108    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 816      |
# |    fps              | 9399     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18188    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 820      |
# |    fps              | 9405     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18262    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 824      |
# |    fps              | 9414     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18403    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 828      |
# |    fps              | 9419     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18474    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 832      |
# |    fps              | 9422     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18586    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 836      |
# |    fps              | 9422     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18655    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 840      |
# |    fps              | 9426     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18739    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 844      |
# |    fps              | 9428     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18843    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 848      |
# |    fps              | 9434     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 18924    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 852      |
# |    fps              | 9433     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19009    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 856      |
# |    fps              | 9453     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19141    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 860      |
# |    fps              | 9450     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19207    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 864      |
# |    fps              | 9449     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19264    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 868      |
# |    fps              | 9454     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19358    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 872      |
# |    fps              | 9457     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19459    |
# ----------------------------------
# Eval num_timesteps=19520, episode_reward=9.40 +/- 0.80
# Episode length: 9.40 +/- 0.80
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 9.4      |
# |    mean_reward      | 9.4      |
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 876      |
# |    fps              | 9379     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19539    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 880      |
# |    fps              | 9390     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19626    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 884      |
# |    fps              | 9397     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19700    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 888      |
# |    fps              | 9403     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19802    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 892      |
# |    fps              | 9407     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19896    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 896      |
# |    fps              | 9407     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19993    |
# ----------------------------------

# %%
DQN_Path=os.path.join('Training','Saved Models','DQN_Model_cartpole')

# %%
model.save(DQN_Path)
